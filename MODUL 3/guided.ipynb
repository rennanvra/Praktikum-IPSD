# %% [markdown]
# <a href="https://colab.research.google.com/github/rennanvra/Praktikum-IPSD/blob/main/MODUL%203/guided.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #visualisasi
import seaborn as sns #visualisasi

from sklearn.impute import KNNImputer #imputasi
from sklearn.preprocessing import StandardScaler #scaling
from imblearn.over_sampling import SMOTE #oversampling
from wordcloud import WordCloud #visualisasi kata

# %% [markdown]
# ## load data

# %%
df = pd.read_csv('diabetes.csv')
df.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      NaN           72.0           35.0      0.0   NaN
# 1          1.0     85.0           66.0           29.0      0.0   NaN
# 2          8.0    183.0           64.0            0.0      0.0  23.3
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627   NaN        1
# 1                     0.351  31.0        0
# 2                     0.672  32.0        1

# %% [markdown]
# ## data understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               691 non-null    float64
#  1   Glucose                   653 non-null    float64
#  2   BloodPressure             614 non-null    float64
#  3   SkinThickness             730 non-null    float64
#  4   Insulin                   576 non-null    float64
#  5   BMI                       538 non-null    float64
#  6   DiabetesPedigreeFunction  691 non-null    float64
#  7   Age                       614 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 54.1 KB

# %%
df.isnull().sum()
# Out:
# Pregnancies                  77
# Glucose                     115
# BloodPressure               154
# SkinThickness                38
# Insulin                     192
# BMI                         230
# DiabetesPedigreeFunction     77
# Age                         154
# Outcome                       0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Pregnancies                 10.026042
# Glucose                     14.973958
# BloodPressure               20.052083
# SkinThickness                4.947917
# Insulin                     25.000000
# BMI                         29.947917
# DiabetesPedigreeFunction    10.026042
# Age                         20.052083
# Outcome                      0.000000
# dtype: float64

# %%
# Function to count outliers using IQR
def count_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return ((data < lower_bound) | (data > upper_bound)).sum()

# Count outliers in each numerical column
outlier_counts = {}
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    outlier_counts[col] = count_outliers_iqr(df[col])

# Convert the results into a DataFrame for easier viewing
outlier_counts_df = pd.DataFrame(list(outlier_counts.items()), columns=['Column', 'Outlier Count'])

# Display the outlier counts DataFrame
outlier_counts_df
# Out:
#                      Column  Outlier Count
# 0               Pregnancies              4
# 1                   Glucose              4
# 2             BloodPressure             39
# 3             SkinThickness              1
# 4                   Insulin             26
# 5                       BMI             14
# 6  DiabetesPedigreeFunction             23
# 7                       Age             16
# 8                   Outcome              0

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# ## EDA

# %%
def plot_histograms(data):
    data.hist(bins=10, figsize=(15, 10), layout=(3, 3),
              color='skyblue', edgecolor='black')
    plt.suptitle('Histograms of Pima Indian Diabetes Dataset Features', fontsize=16)
    plt.show()

plot_histograms(df)

# %%
def plot_boxplots(data):
    plt.figure(figsize=(15, 10))
    for i, column in enumerate(data.columns[:-1]):
        plt.subplot(3, 3, i + 1)
        sns.boxplot(x='Outcome', y=column, data=data)
        plt.title(f'Box Plot of {column} by Diabetes Outcome')
    plt.tight_layout()
    plt.show()

plot_boxplots(df)

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
# Out:
# <Axes: >

# %%
def plot_correlation_heatmap(data):
    plt.figure(figsize=(10, 8))
    correlation_matrix = data.corr()
    sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
    plt.title('Correlation Heatmap of Pima Indian Diabetes Dataset Features', fontsize=16)
    plt.show()

plot_correlation_heatmap(df)

# %%
df_text = pd.read_excel('foodreviews.xlsx') #-> menginput program dlm bentuk teks.
df_text.head(3) #-> #-> untuk menampilkan kolom/baris ke 3
# Out:
#    ProductID  Helpfulness_Score  Rating           Review_Title  \
# 0  CFB001E4K                  1       5  Good Quality Dog Food
# 1  CFB00813G                  0       1      Not as Advertised
# 2  CFB000LQO                  1       4  "Delight" says it all
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...

# %%
text = " ".join(review for review in df_text.Text)

def plot_wordcloud(text): #-> membuat program visualisasi dalam berbentuk teks
    wordcloud = WordCloud(width=800, height=400,
                          background_color='white',
                          colormap='viridis').generate(text)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Reviews', fontsize=16)
    plt.show()

plot_wordcloud(text)

# %% [markdown]
# ## pre processing

# %%
imputer = KNNImputer(n_neighbors=5)
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
x=df.drop('Outcome', axis=1)
y=df['Outcome']

smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(x, y)

sns.countplot(data=df, y=y)
# Out:
# <Axes: xlabel='count', ylabel='Outcome'>

# %%
sns.countplot(data=x_resampled, y=y_resampled)
# Out:
# <Axes: xlabel='count', ylabel='Outcome'>

# %%
# Create a DataFrame from the resampled data
df_resampled = pd.DataFrame(x_resampled, columns=x.columns)
df_resampled['Outcome'] = y_resampled # Add the target variable 'Outcome'

# Now you can access df_resampled
df_resampled['Outcome'].value_counts()
# Out:
# Outcome
# 1.0    500
# 0.0    500
# Name: count, dtype: int64

# %%
df.head(3) #-> untuk menampilkan kolom/baris ke 3
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          6.0    165.2           72.0           35.0      0.0  33.54
# 1          1.0     85.0           66.0           29.0      0.0  34.54
# 2          8.0    183.0           64.0            0.0      0.0  23.30
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  36.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Misalkan x_resampled adalah DataFrame yang sudah ada
df = x_resampled.copy()

# Melakukan scaling dengan StandardScaler
scaler = StandardScaler()
df[df.columns.difference(['Outcome'])] = scaler.fit_transform(df[df.columns.difference(['Outcome'])])

# Menampilkan beberapa baris pertama dari DataFrame hasil scaling
print(df.head())
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.631558  1.341591       0.161680       0.909160 -0.762150  0.145372
# 1    -0.960924 -1.343540      -0.162144       0.525073 -0.762150  0.293760
# 2     1.268551  1.937542      -0.270085      -1.331350 -0.762150 -1.374123
# 3    -0.960924 -1.209618      -0.162144       0.140986  0.158329 -0.661860
# 4    -1.279421  0.759031      -1.565378       0.909160  0.882961  1.563963
#
#    DiabetesPedigreeFunction       Age
# 0                  0.509348  0.239937
# 1                 -0.424792 -0.249485
# 2                  0.661654 -0.151600
# 3                 -1.047552 -1.228329
# 4                  0.105908 -0.053716

# %%
df.head(3) #-> untuk menampilkan kolom/baris ke 3
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness  Insulin       BMI  \
# 0     0.631558  1.341591       0.161680       0.909160 -0.76215  0.145372
# 1    -0.960924 -1.343540      -0.162144       0.525073 -0.76215  0.293760
# 2     1.268551  1.937542      -0.270085      -1.331350 -0.76215 -1.374123
#
#    DiabetesPedigreeFunction       Age
# 0                  0.509348  0.239937
# 1                 -0.424792 -0.249485
# 2                  0.661654 -0.151600
